# %% [markdown]
# <a href="https://colab.research.google.com/github/GitMishka/1/blob/main/2_4_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.to_csv('output.csv', index=False)

# %%
df.head()
df.tail(3)
df.sample(5)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 14        60  '2020/12/14'    104       132     379.3
# 7        450  '2020/12/08'    104       134     253.3
# 13        60  '2020/12/13'    106       128     345.3
# 5         60  '2020/12/06'    102       127     300.0
# 4         45  '2020/12/05'    117       148     406.0

# %%
df.loc[:, 'Pulse']
# Out:
# 0     110
# 1     117
# 2     103
# 3     109
# 4     117
# 5     102
# 6     110
# 7     104
# 8     109
# 9      98
# 10    103
# 11    100
# 12    100
# 13    106
# 14    104
# 15     98
# 16     98
# 17    100
# 18     90
# 19    103
# 20     97
# 21    108
# 22    100
# 23    130
# 24    105
# 25    102
# 26    100
# 27     92
# 28    103
# 29    100
# 30    102
# 31     92
# Name: Pulse, dtype: int64

# %%
df.iloc[0:5, 0:2]
# Out:
#    Duration          Date
# 0        60  '2020/12/01'
# 1        60  '2020/12/02'
# 2        60  '2020/12/03'
# 3        45  '2020/12/04'
# 4        45  '2020/12/05'

# %%
df[df['Pulse']>100]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 10        60  '2020/12/11'    103       147     329.3
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 19        60  '2020/12/19'    103       123     323.0
# 21        60  '2020/12/21'    108       131     364.2
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# ...

# %%
df['Pulse']>100
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24     True
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# Name: Pulse, dtype: bool

# %%
df.isnull().sum()
df.dropna(inplace=True)
df.fillna(0, inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Calories'] = df['Calories'].astype(float)

# %%
df.rename(columns={'Duration': 'ExecriseDuration'}, inplace=True)

# %%
df.groupby('Date')['Calories'].sum()
# Out:
# Date
# 2020-12-01    409.1
# 2020-12-02    479.0
# 2020-12-03    340.0
# 2020-12-04    282.4
# 2020-12-05    406.0
# 2020-12-06    300.0
# 2020-12-07    374.0
# 2020-12-08    253.3
# 2020-12-09    195.1
# 2020-12-10    269.0
# 2020-12-11    329.3
# 2020-12-12    501.4
# 2020-12-13    345.3
# 2020-12-14    379.3
# 2020-12-15    275.0
# 2020-12-16    215.2
# 2020-12-17    300.0
# 2020-12-19    323.0
# 2020-12-20    243.0
# 2020-12-21    364.2
# 2020-12-23    300.0
# 2020-12-24    246.0
# 2020-12-25    334.5
# 2020-12-26    250.0
# 2020-12-27    241.0
# 2020-12-29    280.0
# 2020-12-30    380.3
# 2020-12-31    243.0
# Name: Calories, dtype: float64

# %%
df1 = df[['Date','Pulse']]
df2 = df[['Date', 'Calories']]
merged_df = pd.merge(df1,df2, on='Date')

# %%
df.sort_values(by='Carlories', ascending = False)
