# %% [markdown]
# <a href="https://colab.research.google.com/github/GitMishka/1/blob/main/Yammer_10_25_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
from datetime import datetime

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4b0eea5e-690f-41da-9976-95db4290892b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b0eea5e-690f-41da-9976-95db4290892b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('yammer_10.25.2023.csv')

sorted_df = df.sort_values(by=['Community', 'Score'], ascending=[True, False])

sorted_df
# Out:
#           Display Name                                  Community  \
# 2           Amber Hill                   Morning Pointe of Athens
# 1         Darlene Pope                   Morning Pointe of Athens
# 0    Kayla Hockensmith                   Morning Pointe of Athens
# 3         Jaime Cooper                  Morning Pointe of Calhoun
# 5       Tiffany Murphy  Morning Pointe of Chattanooga Shallowford
# ..                 ...                                        ...
# 86       Nicole Walker    The Lantern at Morning Pointe of Powell
# 85       Kara Greenlee    The Lantern at Morning Pointe of Powell
# 84       Alexis Butler    The Lantern at Morning Pointe of Powell
# 83  Deonna Teffeteller    The Lantern at Morning Pointe of Powell
# 82          Teia Young    The Lantern at Morning Pointe of Powell
#
#     Posted Count  Read Count  Liked Count  Score
# 2              3         114            1   24.6
# 1              3          63            8   16.5
# ...

# %%
#todays date
today = datetime.today().strftime('%Y-%m-%d')
filename = f"Yammer_sorted_{today}.csv"
sorted_df.to_csv(filename, index=False)
files.download(filename)
