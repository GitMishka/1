# %% [markdown]
# <a href="https://colab.research.google.com/github/GitMishka/1/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'Name': ['John', 'Anna', 'Mike', 'Sarah', 'Matthew', 'Laura', 'Tom'],
    'Age': [28, 22, 32, 45, 38, 41, 50],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age          City
# 0     John   28      New York
# 1     Anna   22   Los Angeles
# 2     Mike   32       Chicago
# 3    Sarah   45       Houston
# 4  Matthew   38       Phoenix
# 5    Laura   41  Philadelphia
# 6      Tom   50   San Antonio

# %%
print(df.head(3))
# Out:
#    Name  Age         City
# 0  John   28     New York
# 1  Anna   22  Los Angeles
# 2  Mike   32      Chicago

# %%
print(df[df['Age'] > 30])
# Out:
#       Name  Age          City
# 2     Mike   32       Chicago
# 3    Sarah   45       Houston
# 4  Matthew   38       Phoenix
# 5    Laura   41  Philadelphia
# 6      Tom   50   San Antonio

# %%
df['Occupation'] = ['Engineer', 'Doctor', 'Lawyer', 'Nurse', 'Manager', 'Architect', 'Pilot']
df
# Out:
#       Name  Age          City Occupation
# 0     John   28      New York   Engineer
# 1     Anna   22   Los Angeles     Doctor
# 2     Mike   32       Chicago     Lawyer
# 3    Sarah   45       Houston      Nurse
# 4  Matthew   38       Phoenix    Manager
# 5    Laura   41  Philadelphia  Architect
# 6      Tom   50   San Antonio      Pilot

# %%
df['City'] = df['City'].replace('New York', 'Brooklyn')
df
# Out:
#       Name  Age          City Occupation
# 0     John   28      Brooklyn   Engineer
# 1     Anna   22   Los Angeles     Doctor
# 2     Mike   32       Chicago     Lawyer
# 3    Sarah   45       Houston      Nurse
# 4  Matthew   38       Phoenix    Manager
# 5    Laura   41  Philadelphia  Architect
# 6      Tom   50   San Antonio      Pilot

# %%
average_age = df['Age'].mean()
print(average_age)
# Out:
# 36.57142857142857
