# %% [markdown]
# <a href="https://colab.research.google.com/github/GitMishka/1/blob/main/pos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])
# Out:
#      <input type="file" id="files-4304d952-ac68-426c-8ff2-0d220e1ac23e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4304d952-ac68-426c-8ff2-0d220e1ac23e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Assuming you've read your dataset into a pandas dataframe named df
# df = pd.read_csv("your_dataset.csv")

# Step 1: Filter rows where Job Title is one of the mentioned titles or "EXECUTIVE DIRECTOR"
filtered_df = df[df["Job Title (PIT)"].isin(["Business Office Director", "DON", "Director of Nursing", "EXECUTIVE DIRECTOR"])]

# Step 2: Sort the dataframe based on Employee Id and Position Effective Date
sorted_df = filtered_df.sort_values(by=["Employee Id", "Position Effective Date"])

# Step 3: Using the `shift` function, create new columns to capture the previous Job Title and the corresponding Effective Date
sorted_df["Prev Job Title"] = sorted_df.groupby("Employee Id")["Job Title (PIT)"].shift(1)
sorted_df["Prev Effective Date"] = sorted_df.groupby("Employee Id")["Position Effective Date"].shift(1)

# Step 4: Filter rows where the current job title is "EXECUTIVE DIRECTOR" and previous job title is one of the mentioned titles
promoted_df = sorted_df[
    (sorted_df["Job Title (PIT)"] == "EXECUTIVE DIRECTOR") &
    (sorted_df["Prev Job Title"].isin(["Business Office Director", "DON", "Director of Nursing"]))
]

# The resulting `promoted_df` will contain the records of employees who got promoted to "EXECUTIVE DIRECTOR"
print(promoted_df[["Employee Id", "Last Name", "Preferred/First Name", "Prev Effective Date", "Position Effective Date", "Prev Job Title", "Job Title (PIT)"]])
# Out:
#      Employee Id Last Name Preferred/First Name Prev Effective Date  \
# 186        10426  mitchell                 nena            8/2/2023
#
#     Position Effective Date       Prev Job Title     Job Title (PIT)
# 186                9/1/2023  Director of Nursing  EXECUTIVE DIRECTOR
